# %% [markdown]
# ## Chinook database
# ![Chinook Schema](https://s3.amazonaws.com/dq-content/191/chinook-schema.svg)

# %% [markdown]
# ### Connect jupyter notebook to the databse

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# 'Connected: None@chinook.db'

# %% [markdown]
# ### Explore table and views

# %%
# %%sql
# SELECT
#     name,
#     Type
# FROM sqlite_master
# WHERE type IN ("table", "view");
# Out:
# Done.
# [('album', 'table'),
#  ('artist', 'table'),
#  ('customer', 'table'),
#  ('employee', 'table'),
#  ('genre', 'table'),
#  ('invoice', 'table'),
#  ('invoice_line', 'table'),
#  ('media_type', 'table'),
#  ('playlist', 'table'),
#  ('playlist_track', 'table'),
#  ('track', 'table')]

# %% [markdown]
# ### Number of records sold for each genre in USA

# %%
# %%sql
# With track_invoice AS
# (
#     SELECT g.name, il.quantity
#         FROM track t
#         INNER JOIN invoice_line il
#         ON t.track_id = il.track_id
#         INNER JOIN invoice i
#         ON i.invoice_id = il.invoice_id
#         INNER JOIN genre g
#         ON g.genre_id = t.genre_id
#         WHERE i.billing_country = "USA"
# )
# SELECT
#     name,
#     sum(quantity) as num_of_tracks
# FROM track_invoice
# GROUP BY name
# ORDER BY num_of_tracks DESC;
# Out:
# Done.
# [('Rock', 561),
#  ('Alternative & Punk', 130),
#  ('Metal', 124),
#  ('R&B/Soul', 53),
#  ('Blues', 36),
#  ('Alternative', 35),
#  ('Latin', 22),
#  ('Pop', 22),
#  ('Hip Hop/Rap', 20),
#  ('Jazz', 14),
#  ('Easy Listening', 13),
#  ('Reggae', 6),
#  ('Electronica/Dance', 5),
#  ('Classical', 4),
#  ('Heavy Metal', 3),
#  ('Soundtrack', 2),
#  ('TV Shows', 1)]

# %% [markdown]
# Rock, Alternative & Punk, Metal, R&B/Soul and Blues are the top 5 mostly sold genre in the USA.
# Artist Name	Genre
# Regal	Hip-Hop
# Red Tone	Punk
# Meteor and the Girls	Pop
# Slim Jim Bites	Blues
# So for the above new albums, Slim Jim Bites is expected to perfrom much better in USA than other artists

# %% [markdown]
# Total dollar amount of sales assigned to each sales support agent within the company

# %% [markdown]
# ###  Total dollar amount of sales assigned to each sales support agent within the company

# %%
# %%sql
# With employee_sales AS
# (
#     SELECT e.first_name, e.last_name, i.total
#         FROM employee e
#             LEFT JOIN
#                 customer c ON e.employee_id = support_rep_id
#                     LEFT JOIN
#                         invoice i ON i.customer_id = c.customer_id
# )
# SELECT
#     first_name || " " || last_name AS name,
#     sum(total) as sales_made
# FROM employee_sales
# GROUP BY name
# ORDER BY sales_made DESC;
# Out:
# Done.
# [('Jane Peacock', 1731.510000000004),
#  ('Margaret Park', 1584.0000000000032),
#  ('Steve Johnson', 1393.9200000000028),
#  ('Andrew Adams', None),
#  ('Laura Callahan', None),
#  ('Michael Mitchell', None),
#  ('Nancy Edwards', None),
#  ('Robert King', None)]

# %% [markdown]
# Jane Peacock, Margaret Park and Steve Johnson are only employees who were able to make sales while others were unable to make sales. Jane is the most hard workign eployee.

# %% [markdown]
# ### Information on purchase for different countries

# %%
# %%sql
#
# WITH customer_invoice
#     AS (
#         SELECT *
#         FROM customer c
#         LEFT JOIN
#             (
#                 SELECT customer_id, sum(total) as total,
#                 avg(total) as avg_order
#                 FROM invoice
#                 GROUP BY customer_id
#             )
#         i ON c.customer_id = i.customer_id
#     )
# SELECT
#     new_country,
#     sum(num) as total_customer,
#     sum(total) as total_sales,
#     total/num as avg_sales_per_customer,
#     avg(avg_order) as avg_order
#     FROM
#     (
#     SELECT
#         CASE WHEN num = 1 THEN 'Other'
#             ELSE country end AS new_country,
#             num, total, avg_order
#         FROM
#             (
#                 SELECT country,
#                     count(*) as num,
#                     sum(total) as total,
#                     avg(avg_order) as avg_order
#                     FROM customer_invoice
#                     GROUP BY country
#             )
#     )
#     GROUP BY new_country
#     ORDER BY CASE WHEN num = 1 then 0
#     ELSE 1 END DESC, total_sales DESC;

# %% [markdown]
# There are more customers in USA but this also shows the fact that the per person spending is less in India

# %% [markdown]
# ### Total number of invoices in which all the tracks present in the album were purchased or not

# %%
# %%sql
# With invoice_track AS
# (
# SELECT a.invoice_id, b.album_id, COUNT(DISTINCT a.track_id) AS invoice_track_num
#     FROM invoice_line a
#     INNER JOIN
#     track b
#     USING(track_id)
#     GROUP BY a.invoice_id, b.album_id
# ),
# album_track AS
# (
#     SELECT album_id, COUNT(track_id) as album_track_num
#     FROM album
#     LEFT JOIN
#     track
#     USING(album_id)
#     GROUP BY album_id
# ),
# purchase AS
# (
#     SELECT CASE WHEN album_track_num = invoice_track_num THEN "Full album"
#     ELSE "Individual track" END AS purchase_type,
#     invoice_id
#     FROM album_track
#     LEFT JOIN
#     invoice_track
#     USING(album_id)
# )
# SELECT purchase_type , COUNT(DISTINCT invoice_id) AS invoice_num,
# CAST(COUNT(DISTINCT invoice_id) AS float)*100/(SELECT COUNT( DISTINCT invoice_id) FROM purchase) AS pert_of_invoice
# FROM purchase
# GROUP BY purchase_type;
# Out:
# Done.
# [('Full album', 201, 32.73615635179153),
#  ('Individual track', 500, 81.43322475570032)]

# %% [markdown]
# Most of the purchase made were individual track purchase. So it is better to change our strategry of focusing on selling the top popular tracks from the given album than the whole list of tracks for that albu,

# %% [markdown]
# ### Which artist is used in the most playlists?

# %%
# %%sql
# WITH playlist_info AS
# (
#     SELECT a.playlist_id, a.name, b.track_id
#     FROM playlist a
#     LEFT JOIN
#     playlist_track b
#     USING(playlist_id)
# ),
# artist_info AS
# (
#     SELECT a.artist_id, a.name, b.album_id
#     FROM artist a
#     LEFT JOIN
#     album b
#     USING(artist_id)
# ),
# all_info AS
# (
#     SELECT a.name AS playlist, b.name AS artist, c.track_id
#     FROM playlist_info a
#     LEFT JOIN
#     track c
#     ON a.track_id = c.track_id
#     LEFT JOIN artist_info b
#     ON
#     b.album_id = c.album_id
#
# )
# SELECT artist, COUNT(distinct playlist) AS num_times_artist_present,
# COUNT(playlist) as num_of_features
#     FROM all_info
#     GROUP BY artist
#     ORDER BY num_times_artist_present DESC;
# Out:
# Done.
# [('Eugene Ormandy', 6, 15),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 5, 10),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 5, 13),
#  ('English Concert & Trevor Pinnock', 5, 9),
#  ("The King's Singers", 5, 10),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 4, 5),
#  ('Adrian Leaper & Doreen de Feis', 4, 5),
#  ('Alberto Turco & Nova Schola Gregoriana', 4, 5),
#  ('Antal Doráti & London Symphony Orchestra', 4, 5),
#  ('Barry Wordsworth & BBC Concert Orchestra', 4, 5),
#  ('Berliner Philharmoniker & Hans Rosbaud', 4, 5),
#  ('Boston Symphony Orchestra & Seiji Ozawa', 4, 5),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 4, 5),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 4, 5),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 4, 5),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 4, 5),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 4, 5),
#  ('Gustav Mahler', 4, 5),
#  ('James Levine', 4, 5),
#  ('Julian Bream', 4, 5),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", 4, 5),
#  ('Luciano Pavarotti', 4, 5),
#  ('Martin Roscoe', 4, 5),
#  ('Maurizio Pollini', 4, 5),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 4, 5),
#  ('Michael Tilson Thomas & San Francisco Symphony', 4, 10),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 4, 5),
#  ('Philharmonia Orchestra & Sir Neville Marriner', 4, 5),
#  ('Philip Glass Ensemble', 4, 5),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', 4, 5),
#  ('Scholars Baroque Ensemble', 4, 5),
#  ('Sir Georg Solti & Wiener Philharmoniker', 4, 5),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 4, 5),
#  ('Ton Koopman', 4, 5),
#  ('Wilhelm Kempff', 4, 5),
#  ('Yo-Yo Ma', 4, 5),
#  ('Aaron Copland & London Symphony Orchestra', 3, 4),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 3, 4),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 3, 4),
#  ('Accept', 3, 15),
#  ('Alice In Chains', 3, 37),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 3, 4),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 3, 4),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 3, 4),
#  ('Caetano Veloso', 3, 63),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 3, 4),
#  ('Chico Buarque', 3, 87),
#  ('Choir Of Westminster Abbey & Simon Preston', 3, 4),
#  ("Christopher O'Riley", 3, 4),
#  ('Djavan', 3, 83),
#  ('Edo de Waart & San Francisco Symphony', 3, 4),
#  ('Emerson String Quartet', 3, 4),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 3, 4),
#  ('Eric Clapton', 3, 145),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 3, 4),
#  ('Fretwork', 3, 4),
#  ('Gerald Moore', 3, 4),
#  ('Gilberto Gil', 3, 82),
#  ('Gonzaguinha', 3, 44),
#  ('Göteborgs Symfoniker & Neeme Järvi', 3, 4),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 3, 4),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 3, 4),
#  ('Iron Maiden', 3, 516),
#  ('Itzhak Perlman', 3, 4),
#  ('Leonard Bernstein & New York Philharmonic', 3, 4),
#  ('Les Arts Florissants & William Christie', 3, 4),
#  ('London Symphony Orchestra & Sir Charles Mackerras', 3, 4),
#  ('Metallica', 3, 296),
#  ('Michele Campanella', 3, 4),
#  ('Mötley Crüe', 3, 52),
#  ('Nash Ensemble', 3, 4),
#  ('Nirvana', 3, 93),
#  ('Orchestra of The Age of Enlightenment', 3, 4),
#  ('Otto Klemperer & Philharmonia Orchestra', 3, 4),
#  ('Ozzy Osbourne', 3, 79),
#  ('Pearl Jam', 3, 177),
#  ('Roger Norrington, London Classical Players', 3, 4),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 3, 4),
#  ('Sergei Prokofiev & Yuri Temirkanov', 3, 4),
#  ('Soundgarden', 3, 49),
#  ('Stone Temple Pilots', 3, 37),
#  ('Temple of the Dog', 3, 31),
#  ('The 12 Cellists of The Berlin Philharmonic', 3, 4),
#  ('Yehudi Menuhin', 3, 4),
#  (None, 2, 4),
#  ('AC/DC', 2, 37),
#  ('Aerosmith', 2, 45),
#  ('Alanis Morissette', 2, 39),
#  ('Antônio Carlos Jobim', 2, 64),
#  ('Apocalyptica', 2, 24),
#  ('Audioslave', 2, 81),
#  ('BackBeat', 2, 36),
#  ('Black Sabbath', 2, 36),
#  ('Body Count', 2, 51),
#  ('Bruce Dickinson', 2, 33),
#  ('Chico Science & Nação Zumbi', 2, 108),
#  ('Cidade Negra', 2, 76),
#  ('Cássia Eller', 2, 62),
#  ('Deep Purple', 2, 226),
#  ('Def Leppard', 2, 48),
#  ('Dread Zeppelin', 2, 3),
#  ('Ed Motta', 2, 42),
#  ('Elis Regina', 2, 31),
#  ('Faith No More', 2, 145),
#  ('Falamansa', 2, 33),
#  ('Foo Fighters', 2, 101),
#  ('Funk Como Le Gusta', 2, 48),
#  ('Green Day', 2, 83),
#  ("Guns N' Roses", 2, 114),
#  ('Habib Koité and Bamada', 2, 6),
#  ('House Of Pain', 2, 57),
#  ('Incognito', 2, 39),
#  ('James Brown', 2, 60),
#  ('Jamiroquai', 2, 96),
#  ('Joe Satriani', 2, 30),
#  ('Jorge Ben', 2, 31),
#  ('Jota Quest', 2, 36),
#  ('Judas Priest', 2, 33),
#  ('Kiss', 2, 104),
#  ('Led Zeppelin', 2, 252),
#  ('Legião Urbana', 2, 93),
#  ('Lenny Kravitz', 2, 143),
#  ('Miles Davis', 2, 75),
#  ('Milton Nascimento', 2, 55),
#  ('Motörhead', 2, 32),
#  ('Nicolaus Esterhazy Sinfonia', 2, 3),
#  ('Os Paralamas Do Sucesso', 2, 119),
#  ('Page & Plant', 2, 36),
#  ('Passengers', 2, 42),
#  ('Planet Hemp', 2, 48),
#  ('Queen', 2, 94),
#  ('R.E.M.', 2, 96),
#  ('R.E.M. Feat. Kate Pearson', 2, 33),
#  ('Raimundos', 2, 30),
#  ('Red Hot Chili Peppers', 2, 128),
#  ('Rush', 2, 42),
#  ('Santana', 2, 75),
#  ('Scorpions', 2, 25),
#  ('Skank', 2, 57),
#  ('Smashing Pumpkins', 2, 85),
#  ('Spyro Gyra', 2, 54),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', 2, 21),
#  ('The Clash', 2, 54),
#  ('The Cult', 2, 64),
#  ('The Police', 2, 42),
#  ('The Rolling Stones', 2, 111),
#  ('The Tea Party', 2, 76),
#  ('Tim Maia', 2, 67),
#  ('Titãs', 2, 114),
#  ('U2', 2, 333),
#  ('UB40', 2, 42),
#  ('Van Halen', 2, 122),
#  ('Zeca Pagodinho', 2, 57),
#  ('Aaron Goldberg', 1, 2),
#  ('Aisha Duo', 1, 4),
#  ('Amy Winehouse', 1, 46),
#  ('Aquaman', 1, 2),
#  ('Battlestar Galactica', 1, 40),
#  ('Battlestar Galactica (Classic)', 1, 48),
#  ('Billy Cobham', 1, 16),
#  ('Black Label Society', 1, 36),
#  ('Buddy Guy', 1, 22),
#  ('Cake', 1, 2),
#  ('Calexico', 1, 2),
#  ('Chris Cornell', 1, 28),
#  ('Cláudio Zoli', 1, 20),
#  ('Creedence Clearwater Revival', 1, 80),
#  ('David Coverdale', 1, 24),
#  ('Dennis Chambers', 1, 18),
#  ('Frank Sinatra', 1, 48),
#  ('Frank Zappa & Captain Beefheart', 1, 18),
#  ('Gene Krupa', 1, 44),
#  ('Godsmack', 1, 24),
#  ('Heroes', 1, 46),
#  ('JET', 1, 26),
#  ('Jimi Hendrix', 1, 34),
#  ('João Suplicy', 1, 28),
#  ('Karsh Kale', 1, 4),
#  ('Lost', 1, 184),
#  ('Luciana Souza/Romero Lubambo', 1, 2),
#  ('Lulu Santos', 1, 56),
#  ('Marcos Valle', 1, 34),
#  ('Marillion', 1, 20),
#  ('Marisa Monte', 1, 36),
#  ('Marvin Gaye', 1, 36),
#  ('Men At Work', 1, 20),
#  ('Mônica Marianno', 1, 24),
#  ('O Rappa', 1, 34),
#  ('O Terço', 1, 30),
#  ('Olodum', 1, 28),
#  ('Os Mutantes', 1, 28),
#  ("Paul D'Ianno", 1, 20),
#  ('Pink Floyd', 1, 18),
#  ('Raul Seixas', 1, 28),
#  ('Stevie Ray Vaughan & Double Trouble', 1, 20),
#  ('System Of A Down', 1, 22),
#  ('The Black Crowes', 1, 38),
#  ('The Doors', 1, 22),
#  ('The Office', 1, 106),
#  ('The Posies', 1, 4),
#  ('The Who', 1, 40),
#  ('Toquinho & Vinícius', 1, 30),
#  ('Various Artists', 1, 112),
#  ('Velvet Revolver', 1, 26),
#  ('Vinícius De Moraes', 1, 30)]

# %% [markdown]
# Eugene Ormandy is present inthe most playlist but this doesn't account for the popularity. Iron maiden though present in less number of playlist has the highest number of songs present. This might be due to the generation gap where younger people have more songs of iron maiden.

# %% [markdown]
# ### How many tracks have been purchased vs not purchased?

# %%
# %%sql
# WITH track_info AS
# (SELECT track.track_id as album_track,
#     i.track_id  as invoice_track
#     FROM track
#     LEFT JOIN
# (
#     SELECT DISTINCT track_id
#     FROM invoice
#     LEFT JOIN
#     invoice_line
#     USING(invoice_id)
# ) i
# USING(track_id)),
# purchase AS
# (
#     SELECT
#     CASE WHEN album_track = invoice_track then "Purchased"
#     ELSE "Not purchased" END as track_status
#     FROM track_info
# )
# SELECT track_status,
#         COUNT(track_status) AS num_track
# FROM purchase
# GROUP BY track_status;
# Out:
# Done.
# [('Not purchased', 1697), ('Purchased', 1806)]

# %% [markdown]
# ### Is the range of tracks in the store reflective of their sales popularity?

# %%
# %%sql
# SELECT genre.name AS track_range, count(genre.name) AS num_tracks
#     FROM track
#     LEFT JOIN
#     genre
#     USING(genre_id)
#     GROUP BY genre.name
#     ORDER BY num_tracks DESC;
# Out:
# Done.
# [('Rock', 1297),
#  ('Latin', 579),
#  ('Metal', 374),
#  ('Alternative & Punk', 332),
#  ('Jazz', 130),
#  ('TV Shows', 93),
#  ('Blues', 81),
#  ('Classical', 74),
#  ('Drama', 64),
#  ('R&B/Soul', 61),
#  ('Reggae', 58),
#  ('Pop', 48),
#  ('Soundtrack', 43),
#  ('Alternative', 40),
#  ('Hip Hop/Rap', 35),
#  ('Electronica/Dance', 30),
#  ('Heavy Metal', 28),
#  ('World', 28),
#  ('Sci Fi & Fantasy', 26),
#  ('Easy Listening', 24),
#  ('Comedy', 17),
#  ('Bossa Nova', 15),
#  ('Science Fiction', 13),
#  ('Rock And Roll', 12),
#  ('Opera', 1)]

# %% [markdown]
# Rock, Metal and Latin are the 3 genres for which we have more tracks in the store

# %%
# %%sql
# SELECT genre.name as genre_type,
#         SUM(invoice.total) AS total_sales,
#         SUM(invoice.total)/COUNT(invoice_line.track_id) AS sales_per_track,
#         COUNT(DISTINCT invoice_line.track_id) AS track_sold,
#         COUNT(track.track_id) AS total_tracks
#
#
#
#     FROM track
#     LEFT JOIN invoice_line
#     USING(track_id)
#     LEFT JOIN invoice
#     USING(invoice_id)
#     LEFT JOIN genre
#     USING(genre_id)
#     GROUP BY genre.name
#     ORDER BY sales_per_track DESC;
# Out:
# Done.
# [('Hip Hop/Rap', 463.32000000000005, 14.040000000000001, 21, 47),
#  ('Easy Listening', 951.3899999999994, 12.856621621621613, 24, 74),
#  ('Electronica/Dance', 614.7899999999998, 11.177999999999997, 29, 56),
#  ('Blues', 1379.0700000000038, 11.121532258064546, 56, 149),
#  ('R&B/Soul', 1751.310000000005, 11.014528301886823, 55, 165),
#  ('Jazz', 1302.8400000000004, 10.767272727272731, 61, 190),
#  ('Latin', 1705.770000000001, 10.214191616766472, 119, 627),
#  ('Rock', 26751.77999999988, 10.152478178368076, 915, 3017),
#  ('TV Shows', 19.8, 9.9, 2, 93),
#  ('Alternative & Punk', 4841.099999999979, 9.839634146341421, 176, 648),
#  ('Alternative', 1095.9300000000005, 9.366923076923081, 34, 123),
#  ('Soundtrack', 46.529999999999994, 9.306, 5, 43),
#  ('Pop', 568.2599999999998, 9.019999999999996, 25, 86),
#  ('Heavy Metal', 70.29, 8.78625, 7, 29),
#  ('Metal', 5316.299999999997, 8.588529886914374, 238, 755),
#  ('Classical', 361.3499999999999, 7.688297872340423, 16, 105),
#  ('Reggae', 257.40000000000003, 7.354285714285715, 22, 71),
#  ('Drama', 5.9399999999999995, 5.9399999999999995, 1, 64),
#  ('Bossa Nova', None, None, 0, 15),
#  ('Comedy', None, None, 0, 17),
#  ('Opera', None, None, 0, 1),
#  ('Rock And Roll', None, None, 0, 12),
#  ('Sci Fi & Fantasy', None, None, 0, 26),
#  ('Science Fiction', None, None, 0, 13),
#  ('World', None, None, 0, 28)]

# %% [markdown]
# Most sales are coming from the HIP/HOP. So we should have more of the popular genres in the store. Also some of the genres have been unsold at all. So such genres track should not be restocked.
